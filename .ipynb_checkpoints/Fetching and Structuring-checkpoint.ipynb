# %%
import requests, re
import urllib.parse as urlp

from graphviz import Digraph
from bs4 import BeautifulSoup as bs

# %%
redify = lambda s: "\x1b[31m"+s+"\x1b[0m"
flattened = lambda l: [item for sublist in l for item in sublist]

# %%
class Person:
    def __init__(self, name, path):
        self.name = name
        self.path = path
        self.titles = None
        self.father = None
        self.mother = None
        self.spouse = []
        self.issue = []
        self.successor = []
        self.predecessor = []
        self.house = None
    def __repr__(self):
        return "Person(%s, %s)" % (self.name, self.path)
    def __eq__(self, other):
        if isinstance(other, Person):
            return (self.path.split(',')[0].lower() == other.path.split(',')[0].lower())
        else:
            return False
    def __ne__(self, other):
        return (not self.__eq__(other))
    def __hash__(self):
        return hash(self.path)
        
class Peon:
    def __init__(self, name, path = ''):
        self.name = name
        self.path = path
    def __repr__(self):
        return "Peon(%s, %s)" % (self.name, self.path)
    def __eq__(self, other):
        if isinstance(other, Peon):
            return (self.path.split(',')[0].lower() == other.path.split(',')[0].lower())
        else:
            return False
    def __ne__(self, other):
        return (not self.__eq__(other))
    def __hash__(self):
        return hash(self.path)

# %%
base_url = "https://en.wikipedia.org/"

redirects = {}

# %%
class Queue:
    
    def __init__(self):
        self.to_create = set()
        self.new = set()
        self.finished = set()
    def stage(self, p):
        self.new.add(p)
    def commit(self):
        tmp = self.new.difference(self.finished)
        self.to_create.update(tmp)
        self.new = set()
    def push(self, p):
        if p not in self.finished:
            self.to_create.add(p)
    def pop(self):
        offer = self.to_create.pop()
        self.finished.add(offer)
        return offer
    def refresh(self):
        self.new = set()

# %%
def make_singleton(elem, queue):
    refs = elem.find_all('a')
    if len(refs) == 1:
        ret = urlp.unquote(refs[0]['href'])
        peon = Peon(refs[0].text, ret)
    else:
        ret = elem.text
        peon = Peon(ret)
    queue.stage(peon)
    return ret
    
def make_list(elem, queue):
    refs = elem.find_all('a')
    ret = []
    for ref in refs:
        r = urlp.unquote(ref['href'])
        queue.stage(Peon(ref.text, r))
        ret.append(r)
    return ret

# %%
def get_infocard(path):
    resp = requests.get(base_url + path)
    txt = resp.text
    s = bs(txt)
    p = r'\"wgPageName\":\"(.+?)\"'
    endpath = '/wiki/' + re.search(p, txt).group(1)
    infocard = s.find_all("table", class_ = "infobox vcard")[0]
    name = s.title.string.replace(' - Wikipedia', '')
    return name, infocard, endpath

# %%
def get_person(path, name, people, queue, onlytitled = False, log = False):
    queue.refresh()
    if path is None:
        if log:
            print(redify("No path supplied:"), name)
        return False
    try:
        name, info, endpath = get_infocard(path)
        if endpath != path:
            redirects[path] = endpath
            path = endpath
            if log:
                print(redify("Redirect:"), path, '->', endpath)
        person = Person(name, path)
        if person in people:
            if log:
                print(redify("Already Exists:"), name, path)
            return True
        rows = info.find_all("tr")
        if 'img' in [x.name for x in rows[1].descendants]:
            person.titles = rows[2].text
        elif onlytitled:
            raise Exception('Untitled.')
        for r in rows:
            if len(r.contents) == 2 and r.contents[0].name == 'th':
                if "Mother" in r.contents[0].text:
                    person.mother = make_singleton(r.contents[1], queue)
                if "Father" in r.contents[0].text:
                    person.father = make_singleton(r.contents[1], queue)
                if "Issue" in r.contents[0].text:
                    person.issue = make_list(r.contents[1], queue)
                if "Spouse" in r.contents[0].text:
                    person.spouse = make_list(r.contents[1], queue)
                if "House" in r.contents[0].text:
                    person.house = make_singleton(r.contents[1], queue)
                if "Predecessor" in r.contents[0].text:
                    person.predecessor = make_list(r.contents[1], queue)
                if "Successor" in r.contents[0].text:
                    person.successor = make_list(r.contents[1], queue)
        people.add(person)
        if log:
            print("Adding", len(queue.new), "new elements")
        queue.commit()
        return True
    except Exception as e:
        print("    ", redify("Error - "), path + ":", e)
        return False

# %%
# queue.stage(Peon("Henry VIII", "/wiki/Henry_VIII"))

# for i in range(150):
#     peon = queue.pop()
#     worked = get_person(peon.path, peon.name)
#     if not worked:
#         people.add(peon)
#     print(peon.name)

# %%
def collect_people(basis_person_name, basis_person_link, count=150, log = True):
    people = set()
    queue = Queue()
    queue.stage(Peon(basis_person_name, basis_person_link))
    queue.commit()
    for i in range(count):
        peon = queue.pop()
        worked = get_person(peon.path, peon.name, people, queue, log = log)
        if not worked:
            people.add(peon)
        if log:
            print(peon.name)
    return people

# %%
# Remove extra marriage link (helps for removing edges)
def one_marriage_to_rule_them_all(marriage):
    cleaned = []
    for bond in marriage:
        if bond not in cleaned and (bond[1], bond[0]) not in cleaned:
            cleaned.append(bond)
    return cleaned

# Get actual link from redirected links
def final(x):
    return redirects[x] if x in redirects else x

# %%
# Transform list of people into graph of relations
# List of people (nodes) and lists of edges (child relationships, marriage, crown pathways)
def make_nodegraph_parts(people):
    nodes = []
    childrels = set()
    marriage = set()
    crown = set()

    # ppl = [p for p in people if isinstance(p, Person)]
    for person in people:

        if isinstance(person, Person):
            nodes.append((person.path, person.name, person.house))
            childrels.update({(person.path, final(x)) for x in person.issue})
            marriage.update({(person.path, final(x)) for x in person.spouse})
            crown.update({(person.path, final(x)) for x in person.successor})
            crown.update({(final(x),person.path) for x in person.predecessor})
            if person.mother is not None:
                childrels.add((final(person.mother), person.path))
            if person.father is not None:
                childrels.add((final(person.father), person.path))
    #     else:
    #         nodes.append((person.path, person.name, 'None'))

    nodelinks = [x[0] for x in nodes]
    houses = [x[2] for x in nodes]
    crown = [x for x in crown if x[0] in nodelinks and x[1] in nodelinks]
    marriage = [x for x in marriage if x[0] in nodelinks and x[1] in nodelinks]
    childrels = [x for x in childrels if x[0] in nodelinks and x[1] in nodelinks]

    marriage = one_marriage_to_rule_them_all(marriage)
    
    return nodes, childrels, marriage, crown

# %%
# Functions to remove non-cycle elements, so that the circular ones are really highlighted
# TODO: can probably be improved by using find-cycles graph functions instead of recursing on find-leafs

# Find unimportant people (with only one relation; graph edges)
def get_leafs(crown, marriage, childrels):
    nodepaths = crown + marriage + childrels
    relinstances = flattened(nodepaths)
    relinstances_notkids = flattened(crown + marriage) + [x[0] for x in childrels]
    leafs = [x for x in relinstances if relinstances.count(x) < 2] 
    leafs += [x for x in relinstances_notkids if relinstances_notkids.count(x) == 0]
    return list(set(leafs))

# Remove unimportant people
def remove_leafs(nodes, crown, marriage, childrels, leafs):
    nodes = [x for x in nodes if x[0] not in leafs]
    crown = [x for x in crown if x[0] not in leafs and x[1] not in leafs]
    marriage = [x for x in marriage if x[0] not in leafs and x[1] not in leafs]
    childrels = [x for x in childrels if x[0] not in leafs and x[1] not in leafs]
    return nodes, crown, marriage, childrels
    
# Recursively find and remove unimportant people
def prune(nodes, crown, marriage, childrels, backoff_limit=100):
    leafs = get_leafs(crown, marriage, childrels)
    while len(leafs)>0 and backoff_limit > 0:
        nodes, crown, marriage, childrels = remove_leafs(nodes, crown, marriage, childrels, leafs)
        leafs = get_leafs(crown, marriage, childrels)
    return nodes, crown, marriage, childrels

# %%
collect_people("Henry VIII", "/wiki/Henry_VIII", 50)
# Out:
# 16
# Henry VIII
# 4
# Catherine Howard
# 2
# Joyce Culpeper
# Redirect: /wiki/Henry_VIII_of_England -> /wiki/Henry_VIII
# Exists: Henry VIII /wiki/Henry_VIII
# Henry VIII of England
# 4
# Anne Boleyn
# Redirect: /wiki/Edward_VI -> /wiki/Edward_VI_of_England
# 6
# Edward VI
# 4
# Jane Seymour
# 7
# Mary I of England
#      Error -  /wiki/Illegitimate_child: list index out of range
# illegitimate
# 3
# Henry, Duke of Cornwall
# 4
# Anne of Cleves
# 6
# Elizabeth I of England
#      Error -  /wiki/House_of_Howard: list index out of range
# Howard
# 7
# Catherine of Aragon
#      Error -  /wiki/Margery_Wentworth: list index out of range
# Margery Wentworth
#      Error -  /wiki/John_Seymour_(1474–1536): list index out of range
# Sir John Seymour
# Redirect: /wiki/Elizabeth_I_of_England -> /wiki/Elizabeth_I
# Exists: Elizabeth I /wiki/Elizabeth_I
# Elizabeth I of England
# 10
# Elizabeth of York
# 12
# Ferdinand II of Aragon
# 12
# Henry VII
# Redirect: /wiki/Mary_I -> /wiki/Mary_I_of_England
# Exists: Mary I of England /wiki/Mary_I_of_England
# Mary I
#      Error -  /wiki/House_of_La_Marck: list index out of range
# La Marck
# 1
# Alonso, Archbishop of Zaragoza and Viceroy of Aragon
# 3
# Lord Edmund Howard
# Redirect: /wiki/King_Henry_VII -> /wiki/Henry_VII_of_England
# Exists: Henry VII of England /wiki/Henry_VII_of_England
# King Henry VII
# 4
# Edmund Tudor, 1st Earl of Richmond
# 11
# Edward IV of England
# Redirect: /wiki/Henry_VIII,_King_of_England -> /wiki/Henry_VIII
# Exists: Henry VIII /wiki/Henry_VIII
# Henry VIII, King of England
# 10
# Elizabeth Woodville
# 3
# Maria of Jülich-Berg
# Redirect: /wiki/Richard_of_Shrewsbury -> /wiki/Richard_of_Shrewsbury,_Duke_of_York
# 4
# Richard, Duke of York
# Redirect: /wiki/Lady_Elizabeth_Howard -> /wiki/Elizabeth_Boleyn,_Countess_of_Wiltshire
# 3
# Lady Elizabeth Howard
#      Error -  /wiki/Richard_Grey: list index out of range
# Sir Richard Grey
# Redirect: /wiki/Richard_III -> /wiki/Richard_III_of_England
# 8
# Richard III
# Redirect: /wiki/Cecily_Neville -> /wiki/Cecily_Neville,_Duchess_of_York
# 11
# Cecily Neville
# 3
# Sibylle of Brandenburg
# 8
# Catherine of Valois
# 9
# Margaret, Queen of Scots
# Redirect: /wiki/Henry_VII,_King_of_England -> /wiki/Henry_VII_of_England
# Exists: Henry VII of England /wiki/Henry_VII_of_England
# Henry VII, King of England
# 8
# Henry VI
# 6
# Isabella, Queen of Portugal
# Redirect: /wiki/John_II_of_Aragon_and_Navarre -> /wiki/John_II_of_Aragon
# 13
# John II of Aragon and Navarre
# 4
# Margaret, Duchess of Burgundy
# 1
# Jasper, Duke of Bedford
# 6
# Germaine of Foix
# 4
# Afonso, Prince of Portugal
# 4
# John, Prince of Asturias
# Redirect: /wiki/Charles_of_Viana -> /wiki/Charles,_Prince_of_Viana
# 6
# Charles IV of Navarre
# Redirect: /wiki/Edward_V -> /wiki/Edward_V_of_England
# 5
# Edward V
# Redirect: /wiki/Arthur,_Viscount_Lisle -> /wiki/Arthur_Plantagenet,_1st_Viscount_Lisle
# 4
# Arthur, Viscount Lisle
# {Peon(Howard, /wiki/House_of_Howard),
#  Peon(La Marck, /wiki/House_of_La_Marck),
#  Peon(Margery Wentworth, /wiki/Margery_Wentworth),
#  Peon(Sir John Seymour, /wiki/John_Seymour_(1474–1536)),
#  Peon(Sir Richard Grey, /wiki/Richard_Grey),
#  Peon(illegitimate, /wiki/Illegitimate_child),
#  Person(Afonso, Prince of Portugal, /wiki/Afonso,_Prince_of_Portugal),
#  Person(Alonso de Aragón, /wiki/Alonso_de_Aragón),
#  Person(Anne Boleyn, /wiki/Anne_Boleyn),
#  Person(Anne of Cleves, /wiki/Anne_of_Cleves),
#  Person(Arthur Plantagenet, 1st Viscount Lisle, /wiki/Arthur_Plantagenet,_1st_Viscount_Lisle),
#  Person(Catherine Howard, /wiki/Catherine_Howard),
#  Person(Catherine of Aragon, /wiki/Catherine_of_Aragon),
#  Person(Catherine of Valois, /wiki/Catherine_of_Valois),
#  Person(Cecily Neville, Duchess of York, /wiki/Cecily_Neville,_Duchess_of_York),
#  Person(Charles, Prince of Viana, /wiki/Charles,_Prince_of_Viana),
#  Person(Edmund Tudor, 1st Earl of Richmond, /wiki/Edmund_Tudor,_1st_Earl_of_Richmond),
#  Person(Edward IV of England, /wiki/Edward_IV_of_England),
#  Person(Edward V of England, /wiki/Edward_V_of_England),
#  Person(Edward VI of England, /wiki/Edward_VI_of_England),
#  Person(Elizabeth Boleyn, Countess of Wiltshire, /wiki/Elizabeth_Boleyn,_Countess_of_Wiltshire),
#  Person(Elizabeth I, /wiki/Elizabeth_I),
#  Person(Elizabeth Woodville, /wiki/Elizabeth_Woodville),
#  Person(Elizabeth of York, /wiki/Elizabeth_of_York),
#  Person(Ferdinand II of Aragon, /wiki/Ferdinand_II_of_Aragon),
#  Person(Germaine of Foix, /wiki/Germaine_of_Foix),
#  Person(Henry VI of England, /wiki/Henry_VI_of_England),
#  Person(Henry VII of England, /wiki/Henry_VII_of_England),
#  Person(Henry VIII, /wiki/Henry_VIII),
#  Person(Henry, Duke of Cornwall, /wiki/Henry,_Duke_of_Cornwall),
#  Person(Isabella of Aragon, Queen of Portugal, /wiki/Isabella_of_Aragon,_Queen_of_Portugal),
#  Person(Jane Seymour, /wiki/Jane_Seymour),
#  Person(Jasper Tudor, /wiki/Jasper_Tudor),
#  Person(John II of Aragon, /wiki/John_II_of_Aragon),
#  Person(John, Prince of Asturias, /wiki/John,_Prince_of_Asturias),
#  Person(Joyce Culpeper, /wiki/Joyce_Culpeper),
#  Person(Lord Edmund Howard, /wiki/Lord_Edmund_Howard),
#  Person(Margaret Tudor, /wiki/Margaret_Tudor),
#  Person(Margaret of York, /wiki/Margaret_of_York),
#  Person(Maria of Jülich-Berg, /wiki/Maria_of_Jülich-Berg),
#  Person(Mary I of England, /wiki/Mary_I_of_England),
#  Person(Richard III of England, /wiki/Richard_III_of_England),
#  Person(Richard of Shrewsbury, Duke of York, /wiki/Richard_of_Shrewsbury,_Duke_of_York),
#  Person(Sibylle of Brandenburg, /wiki/Sibylle_of_Brandenburg)}

# %%
housecolors = {'/wiki/House_of_Enríquez': 'yellow',
 '/wiki/House_of_Grey': 'grey',
 '/wiki/House_of_Howard': 'black',
 '/wiki/House_of_La_Marck': 'purple',
 '/wiki/House_of_Stewart': 'red',
 '/wiki/House_of_Stuart': 'orange',
 '/wiki/House_of_Trastámara': 'pink',
 '/wiki/House_of_Tudor': 'blue',
 '/wiki/House_of_Évreux': 'green',
 'None': 'black',
 'YorkTudor': 'violet',
 '[]': 'black'}

# %%
dot = Digraph(comment='The Round Table')

# %%
for p, n, h in nodes:
    dot.node(p, n) #, color = housecolors[str(h)])

for a, b in list(marriage):
    dot.edge(a, b, color = 'red', style = 'dashed', arrowhead = 'none')
for a, b in list(crown):
    dot.edge(a, b, color = 'gold')
for a, b in list(childrels):
    dot.edge(a, b, color = 'black')

# %%
dot

# %%
marriage
# Out:
# [('/wiki/Francis_II_of_France', '/wiki/Mary,_Queen_of_Scots'),
#  ('/wiki/James_IV_of_Scotland', '/wiki/Margaret_Tudor'),
#  ('/wiki/Edward_IV_of_England', '/wiki/Elizabeth_Woodville'),
#  ('/wiki/Elizabeth_Woodville', '/wiki/Edward_IV_of_England'),
#  ('/wiki/Madeleine_of_Valois', '/wiki/James_V_of_Scotland'),
#  ('/wiki/Margaret_Tudor', '/wiki/Henry_Stewart,_1st_Lord_Methven'),
#  ('/wiki/Duchess_Charlotte_of_Brunswick-Lüneburg',
#   "/wiki/Rinaldo_d'Este_(1655–1737)"),
#  ('/wiki/Frances_Grey,_Duchess_of_Suffolk',
#   '/wiki/Henry_Grey,_1st_Duke_of_Suffolk'),
#  ('/wiki/Anna_of_Saxony,_Landgravine_of_Hesse',
#   '/wiki/Louis_I,_Landgrave_of_Hesse'),
#  ('/wiki/Germaine_of_Foix', '/wiki/Johann_of_Brandenburg-Ansbach'),
#  ('/wiki/Frederick_V_of_the_Palatinate',
#   '/wiki/Elizabeth_Stuart,_Queen_of_Bohemia'),
#  ('/wiki/Jacquetta_of_Luxembourg', '/wiki/Richard_Woodville,_1st_Earl_Rivers'),
#  ('/wiki/Germaine_of_Foix', '/wiki/Ferdinand_II_of_Aragon'),
#  ('/wiki/John,_Prince_of_Asturias',
#   '/wiki/Margaret_of_Austria,_Duchess_of_Savoy'),
#  ("/wiki/Marie_Louise_d'Orléans", '/wiki/Charles_II_of_Spain'),
#  ('/wiki/Henry_Grey,_1st_Duke_of_Suffolk',
#   '/wiki/Frances_Grey,_Duchess_of_Suffolk'),
#  ('/wiki/Louis_XII_of_France', '/wiki/Mary_Tudor,_Queen_of_France'),
#  ('/wiki/Mary_Tudor,_Queen_of_France', '/wiki/Louis_XII_of_France'),
#  ('/wiki/Frances_Grey,_Duchess_of_Suffolk',
#   '/wiki/Adrian_Stokes_(Master_of_Horse)'),
#  ('/wiki/John_II,_Duke_of_Cleves', '/wiki/Matilda_of_Hesse'),
#  ('/wiki/Philip_II_of_Spain', '/wiki/Mary_I_of_England'),
#  ('/wiki/Louis_I,_Landgrave_of_Hesse',
#   '/wiki/Anna_of_Saxony,_Landgravine_of_Hesse'),
#  ('/wiki/Louis_XII_of_France', '/wiki/Joan_of_France,_Duchess_of_Berry'),
#  ('/wiki/Margaret_of_Austria,_Duchess_of_Savoy',
#   '/wiki/John,_Prince_of_Asturias'),
#  ('/wiki/Margaret_Tudor', '/wiki/James_IV_of_Scotland'),
#  ('/wiki/Margaret_of_Austria,_Duchess_of_Savoy',
#   '/wiki/Philibert_II,_Duke_of_Savoy')]

# %%
dot.render('test-output/round-table.gv', view=True)
# Out:
# 'test-output/round-table.gv.pdf'
